# %% [markdown]
# # Install spleeter

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !apt install ffmpeg flac

# %%
# !pip install spleeter

# %%
from IPython.display import Audio

# %% [markdown]
# # Separate from command line

# %%
#get file from url
#!wget URL

# %%
#Test if the file plays
#Audio('file_name.ext')

# %%
#show spleeter help
#!spleeter -h

# %%
#show spleeter separate help
#!spleeter separate -h

# %%
# !spleeter separate -i "/content/drive/My Drive/FILENAME.flac" -o output/ -p spleeter:5stems-16kHz

# %%
# !cp "/content/output/" "/content/drive/My Drive/spleeter/" -r

# %%
#!apt install flac

# %%
# !find ./ -type f -name "*.wav" -exec flac -f --keep-foreign-metadata "{}" \;
print("WAVs are now FLACs")

# %%
# !find ./ -type f -name "*.wav" -exec rm "{}" \;
print("WAVs are now moved to trash.")
